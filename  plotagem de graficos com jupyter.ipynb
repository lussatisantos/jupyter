# %% [markdown]
# # plotagem de graficos com jupyter

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
linguagens = ['Python', 'Django', 'JavaScript', 'Node', 'HTML/CSS']
qtde = [8, 2, 4, 1, 4]
ax.bar(linguagens, qtde)
# Out:
# <BarContainer object of 5 artists>

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
linguagens = ['Python', 'Django', 'Javascript', 'Node']
qtde = [8, 2, 4, 1]
ax.bar(linguagens, qtde)
# Out:
# <div id='c8ec1694-6061-4481-be23-2100995c20ef'></div>
# <BarContainer object of 4 artists>

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
# %matplotlib inline
x = np.arange(0, math.pi*2, 0.05)
y = np.sin(x)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x, y)
ax.set_title("Onda")
ax.set_xlabel("Angulo")
ax.set_ylabel("Seno")
# Out:
# Text(0, 0.5, 'Seno')
